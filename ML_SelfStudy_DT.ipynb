# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradyumna1312/ML_SelfStudy/blob/main/ML_SelfStudy_DT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pima Indian diabetes data comes from the National Institute of Diabetes and Digestive and Kidney Diseases, which is part of the National Institute of Health. The goal of the dataset is to be able to diagnose whether or not a patient has diabetes based on certain diagnostic measurements that are in the dataset. There were a lot of rules that had to be followed when
# these people were chosen from a larger database. All of the patients here are women who are at least 21 years old and of Pima Indian heritage. The dataset includes 8 attributes and 1 Outcome and are: Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, Diabetes Pedigree
# Function, Age and Outcome

# %% [markdown]
# * Import the necessary Python Packages

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from sklearn import tree
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# * Display first 10 rows of the Pima dataset

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Pradyumna1312/ML_SelfStudy/main/Datasets/diabetes.csv')
print(df.head(10))
x=df.iloc[:,:8].values
y=df.iloc[:,-1].values
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
# 5            5      116             74  ...                     0.201   30        0
# 6            3       78             50  ...                     0.248   26        1
# 7           10      115              0  ...                     0.134   29        0
# 8            2      197             70  ...                     0.158   53        1
# 9            8      125             96  ...                     0.232   54        1
#
# [10 rows x 9 columns]

# %% [markdown]
# *   Convert if any categorical attributes to Binary attributes - No Categorical values
# *   Split the dataset into Training set:80% and Test dataset:20%

# %%
scaler= StandardScaler()
X=scaler.fit_transform(x)
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

# %% [markdown]
# * Train the model using Decision Tree Classifier.

# %%
classifier = DecisionTreeClassifier()
classifier = classifier.fit(X_train, Y_train)

# %% [markdown]
# * Make the predations with test dataset

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# * Find accuracy score, confusion matrix, precision, recall, f1-score, support

# %%
print("Accuracy Score:", metrics.accuracy_score(Y_test,y_pred))
print(confusion_matrix(Y_test, y_pred))
precision = precision_score(Y_test, y_pred,labels=[1,2], average='micro')
print('Precision: %.3f' % precision)
recall = recall_score(Y_test, y_pred, average='binary')
print('Recall: ', recall)
score = f1_score(Y_test, y_pred, average='binary')
print('F-Measure: %.3f' % score)
# Out:
# Accuracy Score: 0.7012987012987013
# [[80 19]
#  [27 28]]
# Precision: 0.596
# Recall:  0.509090909090909
# F-Measure: 0.549

# %% [markdown]
# * Classify the input data (Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin,
# BMI, Diabetes Pedigree Function, Age) = (5, 116, 74, 0, 0, 25.6, 0.201, 30)

# %%
val = classifier.predict([[5, 116, 74, 0, 0, 25.6, 0.201, 30]])
print("Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, DiabetesPedigreeFunction, Age=5, 116, 74, 0, 0, 25.6, 0.201, 30\nThe output when input is as above =", val)
# Out:
# Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, DiabetesPedigreeFunction, Age=5, 116, 74, 0, 0, 25.6, 0.201, 30
# The output when input is as above = [0]

# %% [markdown]
# * Visualise the decision Tree.

# %%
fn=['Pregancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
cn=['0', '1']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(classifier,
               feature_names = fn, 
               class_names=cn,
               filled = True);

# %%
scaler= StandardScaler()
X=scaler.fit_transform(x)
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.05, random_state=0)
classifier = DecisionTreeClassifier(random_state=0)
classifier = classifier.fit(X_train, Y_train)
y_pred = classifier.predict(X_test)
print("Accuracy:", metrics.accuracy_score(Y_test,y_pred))
print(confusion_matrix(Y_test, y_pred))
precision = precision_score(Y_test, y_pred,labels=[1,2], average='micro')
print('Precision: %.3f' % precision)
recall = recall_score(Y_test, y_pred, average='binary')
print('Recall: ', recall)
score = f1_score(Y_test, y_pred, average='binary')
print('F-Measure: %.3f' % score)
val = classifier.predict([[5, 116, 74, 0, 0, 25.6, 0.201, 30]])
print("Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, DiabetesPedigreeFunction, Age=5, 116, 74, 0, 0, 25.6, 0.201, 30\nThe ouput when input is as above =", val)

fn=['Pregancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
cn=['0', '1']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(classifier,
               feature_names = fn, 
               class_names=cn,
               filled = True);
# Out:
# Accuracy: 0.7948717948717948
# [[24  4]
#  [ 4  7]]
# Precision: 0.636
# Recall:  0.6363636363636364
# F-Measure: 0.636
# Pregnancies, Glucose, Blood Pressure, Skin Thickness, Insulin, BMI, DiabetesPedigreeFunction, Age=5, 116, 74, 0, 0, 25.6, 0.201, 30
# The ouput when input is as above = [1]
